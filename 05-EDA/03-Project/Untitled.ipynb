# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
pd.pandas.set_option('display.max_columns', None)

# %%
data = pd.read_csv('Marketing_Analysis.csv',header=None)
# Out:
# C:\Users\Delll\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (0,1,2,3,11,14,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.shape
# Out:
# (45214, 19)

# %%
data.head()
# Out:
#                      0    1                             2        3   \
# 0     banking marketing  NaN                           NaN      NaN
# 1  customer id and age.  NaN  Customer salary and balance.      NaN
# 2            customerid  age                        salary  balance
# 3                     1   58                        100000     2143
# 4                     2   44                         60000       29
#
#                                                   4                     5   \
# 0                                                NaN                   NaN
# 1  Customer marital status and job with education...                   NaN
# 2                                            marital                jobedu
# 3                                            married   management,tertiary
# 4                                             single  technician,secondary
#
#                                            6        7   \
# ...

# %%
data=data.iloc[1:,:]

# %%
data.head(2)
# Out:
#                      0    1                             2        3   \
# 1  customer id and age.  NaN  Customer salary and balance.      NaN
# 2            customerid  age                        salary  balance
#
#                                                   4       5   \
# 1  Customer marital status and job with education...     NaN
# 2                                            marital  jobedu
#
#                                            6        7   \
# 1  particular customer before targeted or not      NaN
# 2                                    targeted  default
#
#                                    8     9             10   11  \
# 1  Loan types: loans or housing loans   NaN  Contact type  NaN
# 2                             housing  loan       contact  day
#
#                  12                13        14     15        16  \
# 1  month of contact  duration of call       NaN    NaN       NaN
# 2             month          duration  campaign  pdays  previous
#
# ...

# %%
data.iloc[0]
# Out:
# 0                                  customer id and age.
# 1                                                   NaN
# 2                          Customer salary and balance.
# 3                                                   NaN
# 4     Customer marital status and job with education...
# 5                                                   NaN
# 6            particular customer before targeted or not
# 7                                                   NaN
# 8                    Loan types: loans or housing loans
# 9                                                   NaN
# 10                                         Contact type
# 11                                                  NaN
# 12                                     month of contact
# 13                                     duration of call
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# ...

# %%
data.iloc[1]
# Out:
# 0     customerid
# 1            age
# 2         salary
# 3        balance
# 4        marital
# 5         jobedu
# 6       targeted
# 7        default
# 8        housing
# 9           loan
# 10       contact
# 11           day
# 12         month
# 13      duration
# 14      campaign
# 15         pdays
# 16      previous
# 17      poutcome
# 18      response
# Name: 2, dtype: object

# %%
data.rename(columns=data.iloc[0]).drop(data.index[0])
# Out:
#       customer id and age.   NaN Customer salary and balance.      NaN  \
# 2               customerid   age                       salary  balance
# 3                        1    58                       100000     2143
# 4                        2    44                        60000       29
# 5                        3    33                       120000        2
# 6                        4    47                        20000     1506
# ...                    ...   ...                          ...      ...
# 45209                45207  51.0                        60000      825
# 45210                45208  71.0                        55000     1729
# 45211                45209  72.0                        55000     5715
# 45212                45210  57.0                        20000      668
# 45213                45211  37.0                       120000     2971
#
#       Customer marital status and job with education level.  \
# ...

# %%
data = pd.read_csv("Marketing_Analysis.csv",skiprows=2)

# %%
data.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %%
data['job'] = data['jobedu'].str.split(',').str[0]

# %%
data['education'] = data['jobedu'].str.split(',').str[1]

# %%
data.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response           job  education
# ...

# %%
data.drop(columns=['jobedu'],inplace=True)

# %%
data.head(1)
# Out:
#    customerid   age  salary  balance  marital targeted default housing loan  \
# 0           1  58.0  100000     2143  married      yes      no     yes   no
#
#    contact  day      month duration  campaign  pdays  previous poutcome  \
# 0  unknown    5  may, 2017  261 sec         1     -1         0  unknown
#
#   response         job education
# 0       no  management  tertiary

# %%
data['year']=pd.DatetimeIndex(data['month']).year

# %%
data['Month']=pd.DatetimeIndex(data['month']).month

# %%
data.head(2)
# Out:
#    customerid   age  salary  balance  marital targeted default housing loan  \
# 0           1  58.0  100000     2143  married      yes      no     yes   no
# 1           2  44.0   60000       29   single      yes      no     yes   no
#
#    contact  ...  duration campaign pdays  previous  poutcome  response  \
# 0  unknown  ...   261 sec        1    -1         0   unknown        no
# 1  unknown  ...   151 sec        1    -1         0   unknown        no
#
#           job  education    year Month
# 0  management   tertiary  2017.0   5.0
# 1  technician  secondary  2017.0   5.0
#
# [2 rows x 22 columns]

# %%
data.drop(columns=['month'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2612/2471837399.py in <module>
# ----> 1 data.drop(columns=['month'],inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
data.head(2)
# Out:
#    customerid   age  salary  balance  marital targeted default housing loan  \
# 0           1  58.0  100000     2143  married      yes      no     yes   no
# 1           2  44.0   60000       29   single      yes      no     yes   no
#
#    contact  day duration  campaign  pdays  previous poutcome response  \
# 0  unknown    5  261 sec         1     -1         0  unknown       no
# 1  unknown    5  151 sec         1     -1         0  unknown       no
#
#           job  education    year  Month
# 0  management   tertiary  2017.0    5.0
# 1  technician  secondary  2017.0    5.0

# %%
data.groupbydata()'.unique()
# Out:
# array([2017.,   nan])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  45211 non-null  int64
#  1   age         45191 non-null  float64
#  2   salary      45211 non-null  int64
#  3   balance     45211 non-null  int64
#  4   marital     45211 non-null  object
#  5   targeted    45211 non-null  object
#  6   default     45211 non-null  object
#  7   housing     45211 non-null  object
#  8   loan        45211 non-null  object
#  9   contact     45211 non-null  object
#  10  day         45211 non-null  int64
#  11  duration    45211 non-null  object
#  12  campaign    45211 non-null  int64
#  13  pdays       45211 non-null  int64
#  14  previous    45211 non-null  int64
#  15  poutcome    45211 non-null  object
#  16  response    45181 non-null  object
#  17  job         45211 non-null  object
#  18  education   45211 non-null  object
# ...

# %%
data.head()
# Out:
#    customerid   age  salary  balance  marital targeted default housing loan  \
# 0           1  58.0  100000     2143  married      yes      no     yes   no
# 1           2  44.0   60000       29   single      yes      no     yes   no
# 2           3  33.0  120000        2  married      yes      no     yes  yes
# 3           4  47.0   20000     1506  married       no      no     yes   no
# 4           5  33.0       0        1   single       no      no      no   no
#
#    contact  day      month duration  campaign  pdays  previous poutcome  \
# 0  unknown    5  may, 2017  261 sec         1     -1         0  unknown
# 1  unknown    5  may, 2017  151 sec         1     -1         0  unknown
# 2  unknown    5  may, 2017   76 sec         1     -1         0  unknown
# 3  unknown    5  may, 2017   92 sec         1     -1         0  unknown
# 4  unknown    5  may, 2017  198 sec         1     -1         0  unknown
#
#   response           job  education
# 0       no    management   tertiary
# ...

# %%
data.isnull().sum()
# Out:
# customerid     0
# age           20
# salary         0
# balance        0
# marital        0
# targeted       0
# default        0
# housing        0
# loan           0
# contact        0
# day            0
# month         50
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# response      30
# job            0
# education      0
# dtype: int64

# %%
data.isna().sum()
# Out:
# customerid     0
# age            0
# salary         0
# balance        0
# marital        0
# targeted       0
# default        0
# housing        0
# loan           0
# contact        0
# day            0
# month         50
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# response      30
# job            0
# education      0
# dtype: int64

# %%
data.groupby(['month'])['month'].count()
# Out:
# month
# apr, 2017     2931
# aug, 2017     6240
# dec, 2017      214
# feb, 2017     2646
# jan, 2017     1402
# jul, 2017     6888
# jun, 2017     5335
# mar, 2017      476
# may, 2017    13747
# nov, 2017     3968
# oct, 2017      738
# sep, 2017      576
# Name: month, dtype: int64

# %%
data['month'].fillna(data['month'].mode()[0],inplace=True)

# %%
data['age'].fillna(data['age'].median(),inplace=True)

# %%
data['response'].mode()[0]
# Out:
# 'no'

# %%
data['response'].fillna(data['response'].mode()[0], inplace=True)

# %%
data.isna().sum()
# Out:
# customerid    0
# age           0
# salary        0
# balance       0
# marital       0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response      0
# job           0
# education     0
# dtype: int64

# %%
data.describe().T
# Out:
#               count          mean           std     min      25%      50%  \
# customerid  45211.0  22606.000000  13051.435847     1.0  11303.5  22606.0
# age         45211.0     40.934795     10.616926    18.0     33.0     39.0
# salary      45211.0  57006.171065  32085.718415     0.0  20000.0  60000.0
# balance     45211.0   1362.272058   3044.765829 -8019.0     72.0    448.0
# day         45211.0     15.806419      8.322476     1.0      8.0     16.0
# campaign    45211.0      2.763841      3.098021     1.0      1.0      2.0
# pdays       45211.0     40.197828    100.128746    -1.0     -1.0     -1.0
# previous    45211.0      0.580323      2.303441     0.0      0.0      0.0
#
#                 75%       max
# customerid  33908.5   45211.0
# age            48.0      95.0
# salary      70000.0  120000.0
# balance      1428.0  102127.0
# day            21.0      31.0
# campaign        3.0      63.0
# pdays          -1.0     871.0
# previous        0.0     275.0

# %%
sns.boxplot(x=data['balance'])
plt.show()

# %%
sns.boxplot(x=data['pdays'])
plt.show()

# %%
data.head()
# Out:
#    customerid   age  salary  balance  marital targeted default housing loan  \
# 0           1  58.0  100000     2143  married      yes      no     yes   no
# 1           2  44.0   60000       29   single      yes      no     yes   no
# 2           3  33.0  120000        2  married      yes      no     yes  yes
# 3           4  47.0   20000     1506  married       no      no     yes   no
# 4           5  33.0       0        1   single       no      no      no   no
#
#    contact  day      month duration  campaign  pdays  previous poutcome  \
# 0  unknown    5  may, 2017  261 sec         1     -1         0  unknown
# 1  unknown    5  may, 2017  151 sec         1     -1         0  unknown
# 2  unknown    5  may, 2017   76 sec         1     -1         0  unknown
# 3  unknown    5  may, 2017   92 sec         1     -1         0  unknown
# 4  unknown    5  may, 2017  198 sec         1     -1         0  unknown
#
#   response           job  education
# 0       no    management   tertiary
# ...

# %% [markdown]
# the job column in the dataset is divided into many sub-categories like technician, blue-collar, services, management, etc. There is no weight or measure given to any value in the ‘job’ column.

# %%
# Let's calculate the percentage of each job status category.
data.job.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
data.head()
# Out:
#    customerid   age  salary  balance  marital targeted default housing loan  \
# 0           1  58.0  100000     2143  married      yes      no     yes   no
# 1           2  44.0   60000       29   single      yes      no     yes   no
# 2           3  33.0  120000        2  married      yes      no     yes  yes
# 3           4  47.0   20000     1506  married       no      no     yes   no
# 4           5  33.0       0        1   single       no      no      no   no
#
#    contact  day      month duration  campaign  pdays  previous poutcome  \
# 0  unknown    5  may, 2017  261 sec         1     -1         0  unknown
# 1  unknown    5  may, 2017  151 sec         1     -1         0  unknown
# 2  unknown    5  may, 2017   76 sec         1     -1         0  unknown
# 3  unknown    5  may, 2017   92 sec         1     -1         0  unknown
# 4  unknown    5  may, 2017  198 sec         1     -1         0  unknown
#
#   response           job  education
# 0       no    management   tertiary
# ...

# %%
data.education.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
data.month.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
data.education.value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='education'>

# %%
data.month.value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='month'>

# %%
data.head()
# Out:
#    customerid   age  salary  balance  marital targeted default housing loan  \
# 0           1  58.0  100000     2143  married      yes      no     yes   no
# 1           2  44.0   60000       29   single      yes      no     yes   no
# 2           3  33.0  120000        2  married      yes      no     yes  yes
# 3           4  47.0   20000     1506  married       no      no     yes   no
# 4           5  33.0       0        1   single       no      no      no   no
#
#    contact  day      month duration  campaign  pdays  previous poutcome  \
# 0  unknown    5  may, 2017  261 sec         1     -1         0  unknown
# 1  unknown    5  may, 2017  151 sec         1     -1         0  unknown
# 2  unknown    5  may, 2017   76 sec         1     -1         0  unknown
# 3  unknown    5  may, 2017   92 sec         1     -1         0  unknown
# 4  unknown    5  may, 2017  198 sec         1     -1         0  unknown
#
#   response           job  education
# 0       no    management   tertiary
# ...

# %%
#plot the scatter plot of balance and salary variable in data

# %%
plt.scatter(x=data.salary,y=data.age)
plt.show()

# %%
data.plot.scatter(x='age',y='balance')
plt.show()

# %% [markdown]
# Pair Plot
#
# Now, let’s plot Pair Plots for the three columns we used in plotting Scatter plots. We’ll use the seaborn library for plotting Pair Plots.

# %%
sns.pairplot(data=data,vars=['salary','balance','age'])
plt.show()

# %%
data[['salary','balance','age']].corr()
# Out:
#            salary   balance       age
# salary   1.000000  0.055469  0.024366
# balance  0.055469  1.000000  0.097753
# age      0.024366  0.097753  1.000000

# %%
sns.heatmap(data[['salary','balance','age']].corr(),annot=True, cmap= 'Reds')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>
