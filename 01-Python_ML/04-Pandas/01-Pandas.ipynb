# %%
import pandas as pd
import os

# %%
os.path.exists('mydata.csv')
# Out:
# False

# %%
os.path.isfile('mydata.csv')
# Out:
# False

# %%
os.path.isdir('mydata.csv')
# Out:
# False

# %%
pd.read_csv('data.csv')
# Out:
#    StudentId FirstName LastName Class
# 0          7     mayur  Jathale     B
# 1          8     Ranit   Mondol     B
# 2          9   Vinayak   navale     B

# %%
ps=pd.read_csv('data1.csv')

# %%
ps
# Out:
#        Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0                    2                1                    0,679005
# 1                    2                1                    0,717298
# 2                    2                1                    0,489336
# 3                    2                1                    0,413957
# 4                    2                1                    0,334292
# ...                ...              ...                         ...
# 10716               12                6                    0,834201
# 10717               12                6                    0,698374
# 10718               12                6                    0,923823
# 10719               12                6                    0,934978
# 10720               12                6                    0,953664
#
#       Initial atomic coordinate v Initial atomic coordinate w  \
# 0                        0,701318                    0,017033
# ...

# %%
# To view first five records

# %%
ps.head()
# Out:
#    Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0                2                1                    0,679005
# 1                2                1                    0,717298
# 2                2                1                    0,489336
# 3                2                1                    0,413957
# 4                2                1                    0,334292
#
#   Initial atomic coordinate v Initial atomic coordinate w  \
# 0                    0,701318                    0,017033
# 1                    0,642129                    0,231319
# 2                    0,303751                    0,088462
# 3                    0,632996                    0,040843
# 4                    0,543401                     0,15989
#
#   Calculated atomic coordinates u' Calculated atomic coordinates v'  \
# 0                         0,721039                         0,730232
# 1                         0,738414                          0,65675
# ...

# %%
# to view specific number of record

# %%
ps.head(2)
# Out:
#    Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0                2                1                    0,679005
# 1                2                1                    0,717298
#
#   Initial atomic coordinate v Initial atomic coordinate w  \
# 0                    0,701318                    0,017033
# 1                    0,642129                    0,231319
#
#   Calculated atomic coordinates u' Calculated atomic coordinates v'  \
# 0                         0,721039                         0,730232
# 1                         0,738414                          0,65675
#
#   Calculated atomic coordinates w'
# 0                         0,017014
# 1                         0,232369

# %%
ps.head(28)
# Out:
#     Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0                 2                1                    0,679005
# 1                 2                1                    0,717298
# 2                 2                1                    0,489336
# 3                 2                1                    0,413957
# 4                 2                1                    0,334292
# 5                 2                1                    0,510664
# 6                 2                1                    0,413957
# 7                 2                1                    0,712552
# 8                 2                1                    0,320995
# 9                 2                1                    0,394742
# 10                2                1                    0,282702
# 11                2                1                    0,320995
# 12                2                1                    0,605258
# ...

# %%
# to view last  5 data of file

# %%
ps.tail()
# Out:
#        Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 10716               12                6                    0,834201
# 10717               12                6                    0,698374
# 10718               12                6                    0,923823
# 10719               12                6                    0,934978
# 10720               12                6                    0,953664
#
#       Initial atomic coordinate v Initial atomic coordinate w  \
# 10716                    0,399891                     0,89127
# 10717                     0,24471                    0,962699
# 10718                    0,568913                    0,819842
# 10719                    0,602319                    0,938889
# 10720                    0,698374                    0,962699
#
#       Calculated atomic coordinates u' Calculated atomic coordinates v'  \
# 10716                         0,841858                         0,405882
# ...

# %%
# view particuler last line data from file

# %%
ps.tail(20)
# Out:
#        Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 10701               12                6                    0,910299
# 10702               12                6                    0,876454
# 10703               12                6                     0,89448
# 10704               12                6                    0,757164
# 10705               12                6                    0,784482
# 10706               12                6                    0,728407
# 10707               12                6                    0,757164
# 10708               12                6                    0,568913
# 10709               12                6                    0,602319
# 10710               12                6                      0,9437
# 10711               12                6                     0,94994
# 10712               12                6                    0,934978
# 10713               12                6                      0,9437
# ...

# %%
df = pd.read_csv('data1.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0                2                1                    0,679005
# 1                2                1                    0,717298
# 2                2                1                    0,489336
# 3                2                1                    0,413957
# 4                2                1                    0,334292
#
#   Initial atomic coordinate v Initial atomic coordinate w  \
# 0                    0,701318                    0,017033
# 1                    0,642129                    0,231319
# 2                    0,303751                    0,088462
# 3                    0,632996                    0,040843
# 4                    0,543401                     0,15989
#
#   Calculated atomic coordinates u' Calculated atomic coordinates v'  \
# 0                         0,721039                         0,730232
# 1                         0,738414                          0,65675
# ...

# %%
df.tail()
# Out:
#        Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 10716               12                6                    0,834201
# 10717               12                6                    0,698374
# 10718               12                6                    0,923823
# 10719               12                6                    0,934978
# 10720               12                6                    0,953664
#
#       Initial atomic coordinate v Initial atomic coordinate w  \
# 10716                    0,399891                     0,89127
# 10717                     0,24471                    0,962699
# 10718                    0,568913                    0,819842
# 10719                    0,602319                    0,938889
# 10720                    0,698374                    0,962699
#
#       Calculated atomic coordinates u' Calculated atomic coordinates v'  \
# 10716                         0,841858                         0,405882
# ...

# %%
#copy 5 five line data to new file

# %%
df = pd.read_csv('data1.csv')

# %%
fline=df.head()

# %%
fline
# Out:
#    Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0                2                1                    0,679005
# 1                2                1                    0,717298
# 2                2                1                    0,489336
# 3                2                1                    0,413957
# 4                2                1                    0,334292
#
#   Initial atomic coordinate v Initial atomic coordinate w  \
# 0                    0,701318                    0,017033
# 1                    0,642129                    0,231319
# 2                    0,303751                    0,088462
# 3                    0,632996                    0,040843
# 4                    0,543401                     0,15989
#
#   Calculated atomic coordinates u' Calculated atomic coordinates v'  \
# 0                         0,721039                         0,730232
# 1                         0,738414                          0,65675
# ...

# %%
fline.to_csv("newdata1.csv")

# %%
# %ls
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is EE0B-F929
#
#  Directory of E:\Data Science\DS\04-Pandas
#
# 24/01/2022  12:05 PM    <DIR>          .
# 24/01/2022  12:05 PM    <DIR>          ..
# 24/01/2022  11:28 AM    <DIR>          .ipynb_checkpoints
# 12/01/2022  01:11 PM           628,633 carbon_nanotubes.csv
# 22/01/2022  12:59 PM                93 data.csv
# 14/01/2022  09:10 PM           767,965 data1.csv
# 24/01/2022  12:05 PM               580 newdata1.csv
# 24/01/2022  12:04 PM            71,472 Untitled.ipynb
#                5 File(s)      1,468,743 bytes
#                3 Dir(s)  155,503,374,336 bytes free

# %%
# To read new data file
pd.read_csv('newdata1.csv')
# Out:
#    Unnamed: 0  Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0           0                2                1                    0,679005
# 1           1                2                1                    0,717298
# 2           2                2                1                    0,489336
# 3           3                2                1                    0,413957
# 4           4                2                1                    0,334292
#
#   Initial atomic coordinate v Initial atomic coordinate w  \
# 0                    0,701318                    0,017033
# 1                    0,642129                    0,231319
# 2                    0,303751                    0,088462
# 3                    0,632996                    0,040843
# 4                    0,543401                     0,15989
#
#   Calculated atomic coordinates u' Calculated atomic coordinates v'  \
# 0                         0,721039                         0,730232
# ...

# %%
df = pd.read_csv('mydata.csv')

# %%
df
# Out:
#        Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0                    2                1                    0,679005
# 1                    2                1                    0,717298
# 2                    2                1                    0,489336
# 3                    2                1                    0,413957
# 4                    2                1                    0,334292
# ...                ...              ...                         ...
# 10716               12                6                    0,834201
# 10717               12                6                    0,698374
# 10718               12                6                    0,923823
# 10719               12                6                    0,934978
# 10720               12                6                    0,953664
#
#       Initial atomic coordinate v Initial atomic coordinate w  \
# 0                        0,701318                    0,017033
# ...

# %%
d1 = pd.read_csv('mydata.csv')

# %%
d1
# Out:
#       Chiral indice n#Chiral indice m#Initial atomic coordinate u#Initial atomic coordinate v#Initial atomic coordinate w#Calculated atomic coordinates u'#Calculated atomic coordinates v'#Calculated atomic coordinates w'
# 0      2#1#"0#679005"#"0#701318"#"0#017033"#"0#721039...
# 1      2#1#"0#717298"#"0#642129"#"0#231319"#"0#738414...
# 2      2#1#"0#489336"#"0#303751"#"0#088462"#"0#477676...
# 3      2#1#"0#413957"#"0#632996"#"0#040843"#"0#408823...
# 4      2#1#"0#334292"#"0#543401"#"0#15989"#"0#303349"...
# ...                                                  ...
# 10716  12#6#"0#834201"#"0#399891"#"0#89127"#"0#841858...
# 10717  12#6#"0#698374"#"0#24471"#"0#962699"#"0#706555...
# 10718  12#6#"0#923823"#"0#568913"#"0#819842"#"0#92940...
# 10719  12#6#"0#934978"#"0#602319"#"0#938889"#"0#94184...
# 10720  12#6#"0#953664"#"0#698374"#"0#962699"#"0#96124...
#
# [10721 rows x 1 columns]

# %%
# list the data with # separated values

# %%
d2 = pd.read_csv('mydata.csv',sep='#')

# %%
d2
# Out:
#        Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0                    2                1                    0#679005
# 1                    2                1                    0#717298
# 2                    2                1                    0#489336
# 3                    2                1                    0#413957
# 4                    2                1                    0#334292
# ...                ...              ...                         ...
# 10716               12                6                    0#834201
# 10717               12                6                    0#698374
# 10718               12                6                    0#923823
# 10719               12                6                    0#934978
# 10720               12                6                    0#953664
#
#       Initial atomic coordinate v Initial atomic coordinate w  \
# 0                        0#701318                    0#017033
# ...

# %%
#Remove header from first line

# %%
d3 = pd.read_csv('data1.csv',sep=',',header=None)

# %%
d3
# Out:
#                      0                1                            2  \
# 0      Chiral indice n  Chiral indice m  Initial atomic coordinate u
# 1                    2                1                     0,679005
# 2                    2                1                     0,717298
# 3                    2                1                     0,489336
# 4                    2                1                     0,413957
# ...                ...              ...                          ...
# 10717               12                6                     0,834201
# 10718               12                6                     0,698374
# 10719               12                6                     0,923823
# 10720               12                6                     0,934978
# 10721               12                6                     0,953664
#
#                                  3                            4  \
# 0      Initial atomic coordinate v  Initial atomic coordinate w
# ...

# %%
# give our custom column name to data

# %%
d5 = pd.read_csv('data1.csv',sep=',',header=None,names=['a','b','c','d','e','f','g','h',])

# %%
d5
# Out:
#                      a                b                            c  \
# 0      Chiral indice n  Chiral indice m  Initial atomic coordinate u
# 1                    2                1                     0,679005
# 2                    2                1                     0,717298
# 3                    2                1                     0,489336
# 4                    2                1                     0,413957
# ...                ...              ...                          ...
# 10717               12                6                     0,834201
# 10718               12                6                     0,698374
# 10719               12                6                     0,923823
# 10720               12                6                     0,934978
# 10721               12                6                     0,953664
#
#                                  d                            e  \
# 0      Initial atomic coordinate v  Initial atomic coordinate w
# ...

# %%
# Skip some records from datasets

# %%
d6 = pd.read_csv('data1.csv',sep=',',header=None,names=['a','b','c','d','e','f','g','h',],skiprows=[0,2,6,8])

# %%
d6
# Out:
#         a  b         c         d         e         f         g         h
# 0       2  1  0,717298  0,642129  0,231319  0,738414   0,65675  0,232369
# 1       2  1  0,334292  0,543401   0,15989  0,303349  0,558807  0,157373
# 2       2  1  0,510664  0,696249  0,255128  0,496977  0,725608   0,25597
# 3       2  1  0,413957  0,632996  0,374176  0,390878  0,657645  0,374735
# 4       2  1  0,712552   0,55479  0,112271  0,750056  0,561494  0,114944
# ...    .. ..       ...       ...       ...       ...       ...       ...
# 10713  12  6  0,834201  0,399891   0,89127  0,841858  0,405882  0,891356
# 10714  12  6  0,698374   0,24471  0,962699  0,706555  0,248416  0,962833
# 10715  12  6  0,923823  0,568913  0,819842  0,929403  0,576284  0,819879
# 10716  12  6  0,934978  0,602319  0,938889  0,941844  0,610608  0,938755
# 10717  12  6  0,953664  0,698374  0,962699  0,961243  0,707812  0,962605
#
# [10718 rows x 8 columns]

# %%
# To consider some values as NAN value

# %%
d7 = pd.read_csv('data1.csv',sep=',',na_values=['0,717298','0,334292'])

# %%
d7
# Out:
#        Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0                    2                1                    0,679005
# 1                    2                1                         NaN
# 2                    2                1                    0,489336
# 3                    2                1                    0,413957
# 4                    2                1                         NaN
# ...                ...              ...                         ...
# 10716               12                6                    0,834201
# 10717               12                6                    0,698374
# 10718               12                6                    0,923823
# 10719               12                6                    0,934978
# 10720               12                6                    0,953664
#
#       Initial atomic coordinate v Initial atomic coordinate w  \
# 0                        0,701318                    0,017033
# ...

# %%
d8 = pd.read_csv('data1.csv',sep=',',na_values=['0,717298','0,334292','0,039796','0,24471'])

# %%
d8
# Out:
#        Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0                    2                1                    0,679005
# 1                    2                1                         NaN
# 2                    2                1                    0,489336
# 3                    2                1                    0,413957
# 4                    2                1                         NaN
# ...                ...              ...                         ...
# 10716               12                6                    0,834201
# 10717               12                6                    0,698374
# 10718               12                6                    0,923823
# 10719               12                6                    0,934978
# 10720               12                6                    0,953664
#
#       Initial atomic coordinate v Initial atomic coordinate w  \
# 0                        0,701318                    0,017033
# ...

# %%
d8
# Out:
#        Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0                    2                1                    0,679005
# 1                    2                1                         NaN
# 2                    2                1                    0,489336
# 3                    2                1                    0,413957
# 4                    2                1                         NaN
# ...                ...              ...                         ...
# 10716               12                6                    0,834201
# 10717               12                6                    0,698374
# 10718               12                6                    0,923823
# 10719               12                6                    0,934978
# 10720               12                6                    0,953664
#
#       Initial atomic coordinate v Initial atomic coordinate w  \
# 0                        0,701318                    0,017033
# ...

# %%
# to get information about the numerical data

# %%
d8.describe()
# Out:
#        Chiral indice n  Chiral indice m
# count     10721.000000     10721.000000
# mean          8.225725         3.337189
# std           2.138919         1.683881
# min           2.000000         1.000000
# 25%           7.000000         2.000000
# 50%           8.000000         3.000000
# 75%          10.000000         5.000000
# max          12.000000         6.000000

# %%
# to find all the column name and it's type

# %%
d8.dtypes
# Out:
# Chiral indice n                      int64
# Chiral indice m                      int64
# Initial atomic coordinate u         object
# Initial atomic coordinate v         object
# Initial atomic coordinate w         object
# Calculated atomic coordinates u'    object
# Calculated atomic coordinates v'    object
# Calculated atomic coordinates w'    object
# dtype: object

# %%
d9 = pd.read_csv('data.csv')

# %%
d9
# Out:
#    StudentId FirstName LastName Class
# 0          7     mayur  Jathale     B
# 1          8     Ranit   Mondol     B
# 2          9   Vinayak   navale     B

# %%
d9.describe()
# Out:
#        StudentId
# count        3.0
# mean         8.0
# std          1.0
# min          7.0
# 25%          7.5
# 50%          8.0
# 75%          8.5
# max          9.0

# %%
d10 = pd.read_csv('data1.csv')

# %%
d10
# Out:
#        Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0                    2                1                    0,679005
# 1                    2                1                    0,717298
# 2                    2                1                    0,489336
# 3                    2                1                    0,413957
# 4                    2                1                    0,334292
# ...                ...              ...                         ...
# 10716               12                6                    0,834201
# 10717               12                6                    0,698374
# 10718               12                6                    0,923823
# 10719               12                6                    0,934978
# 10720               12                6                    0,953664
#
#       Initial atomic coordinate v Initial atomic coordinate w  \
# 0                        0,701318                    0,017033
# ...

# %%
d10.to_csv('newdata2.csv')

# %%
# %ls
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is EE0B-F929
#
#  Directory of E:\Data Science\DS\04-Pandas
#
# 25/01/2022  11:32 AM    <DIR>          .
# 25/01/2022  11:32 AM    <DIR>          ..
# 24/01/2022  11:28 AM    <DIR>          .ipynb_checkpoints
# 12/01/2022  01:11 PM           628,633 carbon_nanotubes.csv
# 22/01/2022  12:59 PM                93 data.csv
# 14/01/2022  09:10 PM           767,965 data1.csv
# 24/01/2022  12:33 PM           767,965 mydata.csv
# 14/01/2022  09:10 PM           767,965 mydata.csv.bak
# 24/01/2022  12:05 PM               580 newdata1.csv
# 25/01/2022  11:32 AM           810,460 newdata2.csv
# 25/01/2022  11:31 AM           169,451 Untitled.ipynb
#                8 File(s)      3,913,112 bytes
#                3 Dir(s)  155,509,936,128 bytes free

# %%
# To remove row index number

# %%
d10.to_csv('newdata3.csv',index=False)

# %%
#  To remove column hearder

# %%
d10.to_csv('newdata4.csv',index=False,header=False)

# %%
# TO use different separter to store data in file

# %%
d10.to_csv('newdata5.csv',index=False,sep='#')

# %%
# store only particuler column in .csv file

# %%
d10.to_csv('newdata6.csv',index=False, columns=['Chiral indice n','Chiral indice m'])

# %%
d11 = pd.read_csv('data1.csv')

# %%
d11
# Out:
#        Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0                    2                1                    0,679005
# 1                    2                1                    0,717298
# 2                    2                1                    0,489336
# 3                    2                1                    0,413957
# 4                    2                1                    0,334292
# ...                ...              ...                         ...
# 10716               12                6                    0,834201
# 10717               12                6                    0,698374
# 10718               12                6                    0,923823
# 10719               12                6                    0,934978
# 10720               12                6                    0,953664
#
#       Initial atomic coordinate v Initial atomic coordinate w  \
# 0                        0,701318                    0,017033
# ...

# %%
# Find all the columns heading of data
d11.columns
# Out:
# Index(['Chiral indice n', 'Chiral indice m', 'Initial atomic coordinate u',
#        'Initial atomic coordinate v', 'Initial atomic coordinate w',
#        'Calculated atomic coordinates u'', 'Calculated atomic coordinates v'',
#        'Calculated atomic coordinates w''],
#       dtype='object')

# %%
#print particuler column of data

d11['Chiral indice n']
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 10716    12
# 10717    12
# 10718    12
# 10719    12
# 10720    12
# Name: Chiral indice n, Length: 10721, dtype: int64

# %%
type(d11['Chiral indice n'])
# Out:
# pandas.core.series.Series

# %%
d11[['Chiral indice n']]
# Out:
#        Chiral indice n
# 0                    2
# 1                    2
# 2                    2
# 3                    2
# 4                    2
# ...                ...
# 10716               12
# 10717               12
# 10718               12
# 10719               12
# 10720               12
#
# [10721 rows x 1 columns]

# %%
type(d11[['Chiral indice n']])
# Out:
# pandas.core.frame.DataFrame

# %%
# To print multiple column name

# %%
d11['Chiral indice n','Chiral indice m']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Chiral indice n', 'Chiral indice m')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# To use list to print multiple column names

# %%
d11[['Chiral indice n','Chiral indice m']]
# Out:
#        Chiral indice n  Chiral indice m
# 0                    2                1
# 1                    2                1
# 2                    2                1
# 3                    2                1
# 4                    2                1
# ...                ...              ...
# 10716               12                6
# 10717               12                6
# 10718               12                6
# 10719               12                6
# 10720               12                6
#
# [10721 rows x 2 columns]

# %%
d11.index
# Out:
# RangeIndex(start=0, stop=10721, step=1)

# %%
##########################################################

# %%
# Excel data manupulation

# %%
t1 = pd.read_excel("LUSID.xlsx")

# %%
t1
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# ...

# %%
# To read particuler sheet from excel sheet

# %%
pd.read_excel("LUSID.xlsx",sheet_name="Add your take on balances")
# Out:
#     Unnamed: 0  Unnamed: 1                                         Unnamed: 2  \
# 0          NaN         NaN                                                NaN
# 1          NaN         NaN                                                NaN
# 2          NaN         NaN                                                NaN
# 3          NaN         NaN                                                NaN
# 4          NaN         NaN                                                NaN
# 5          NaN         NaN                                                NaN
# 6          NaN         NaN                                                NaN
# 7          NaN         NaN                                                NaN
# 8          NaN         NaN                                                NaN
# 9          NaN         NaN                                                NaN
# 10         NaN         NaN                                                NaN
# ...

# %%
# To read html data

# %%
t2 = pd.read_html('https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool')

# %%
t2
# Out:
# [       Season   Age                                     Tm  \
#  0     2008-09  19.0  Did Not Play (other pro league—Spain)
#  1     2009-10  20.0                                    OKC
#  2     2010-11  21.0                                    OKC
#  3     2011-12  22.0                                    OKC
#  4     2012-13  23.0                                    OKC
#  5     2013-14  24.0                                    OKC
#  6     2014-15  25.0                                    OKC
#  7     2015-16  26.0                                    OKC
#  8     2016-17  27.0                                    TOT
#  9     2016-17  27.0                                    ORL
#  10    2016-17  27.0                                    TOR
#  11    2017-18  28.0                                    TOR
#  12    2018-19  29.0                                    TOR
#  13    2019-20  30.0                                    TOR
#  14    2020-21  31.0                                    LAC
# ...

# %%
type(t2)
# Out:
# list

# %%
len(t2)
# Out:
# 6

# %%
t2[0]
# Out:
#        Season   Age                                     Tm  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
t2[2]
# Out:
#        Season   Age   Tm   Lg  Pos      G     GS       MP      FG     FGA  \
# 0     2009-10  20.0  OKC  NBA   PF   73.0    0.0   1323.0   201.0   370.0
# 1     2010-11  21.0  OKC  NBA   PF   82.0   44.0   2216.0   335.0   617.0
# 2     2011-12  22.0  OKC  NBA   PF   66.0   66.0   1792.0   262.0   490.0
# 3     2012-13  23.0  OKC  NBA   PF   80.0   80.0   2486.0   446.0   778.0
# 4     2013-14  24.0  OKC  NBA   PF   81.0   81.0   2666.0   524.0   978.0
# 5     2014-15  25.0  OKC  NBA   PF   64.0   64.0   2116.0   374.0   786.0
# 6     2015-16  26.0  OKC  NBA   PF   78.0   78.0   2500.0   416.0   869.0
# 7     2016-17  27.0  TOT  NBA   PF   79.0   79.0   2422.0   471.0   982.0
# 8     2016-17  27.0  ORL  NBA   PF   56.0   56.0   1710.0   343.0   703.0
# 9     2016-17  27.0  TOR  NBA   PF   23.0   23.0    712.0   128.0   279.0
# 10    2017-18  28.0  TOR  NBA   PF   76.0   76.0   2093.0   379.0   784.0
# 11    2018-19  29.0  TOR  NBA    C   74.0   51.0   2010.0   464.0   877.0
# ...

# %%
t2[2].to_csv('player.csv',index=False)

# %%
type(t2[2])
# Out:
# pandas.core.frame.DataFrame
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\Delll\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Delll\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\Delll\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Delll\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
 #  TO read the data from github always use raw data.
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s = """{
"name" : "sachin",
"phone_no" : 393782,
"company" : ["Google","EY", "Microsoft","Amazon","deloitte"]

}
"""

# %%
import json

# %%
s1=json.loads(s)

# %%
#To Convert json data into tabuler format

# %%
pd.DataFrame(s1)
# Out:
#      name  phone_no    company
# 0  sachin    393782     Google
# 1  sachin    393782         EY
# 2  sachin    393782  Microsoft
# 3  sachin    393782     Amazon
# 4  sachin    393782   deloitte

# %%
pd.DataFrame(s1,columns=['company'])
# Out:
#      company
# 0     Google
# 1         EY
# 2  Microsoft
# 3     Amazon
# 4   deloitte

# %%
# download json data from internet

# %%
import requests

# %%
res = requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45631',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45631/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45631/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45631/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/45631',
#   'id': 1114637540,
#   'node_id': 'PR_kwDOAA0YD84xmNNh',
#   'number': 45631,
#   'title': 'Backport PR #45628 on branch 1.4.x (CI/TST: Call join on server process test)',
#   'user': {'login': 'meeseeksmachine',
#    'id': 39504233,
#    'node_id': 'MDQ6VXNlcjM5NTA0MjMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39504233?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/meeseeksmachine',
#    'html_url': 'https://github.com/meeseeksmachine',
# ...

# %%
js = res.json()

# %%
for i in js:
    print("title: ", i['title'], end=" ")
    print("\n")
# Out:
# title:  Backport PR #45628 on branch 1.4.x (CI/TST: Call join on server process test)
#
# title:  BUG: read_csv with `memory_map=True` on BytesIO object fails
#
# title:  BUG: `set_index` with object column gives wrong stack level in warning
#
# title:  CLN: Use pytest -r to show skipped tests instead of print_skipped.py
#
# title:  BUG: parse_time_string with np.str_ obj
#
# title:  BUG: SeriesGroupBy.value_counts - index name missing in categorical columns
#
# title:  REGR: loc.setitem losing index name when df was empty before
#
# title:  BUG: NumericArray * td64_array
#
# title:  BUG: 1.4.0 does not preserve initially empty Index and appended by `loc` assignment.
#
# title:  BUG: passing a SparseArray to pd.Index - overly eager FutureWarning
#
# title:  BUG: describe does not generate unique values for numbers, inconsistent with nunique
#
# title:  BUG: is_bool_dtype raises AttributeError when checking categorical Series
#
# ...

# %%
for i in js:
    print(i['url'], end="")
    print("\n")
# Out:
# https://api.github.com/repos/pandas-dev/pandas/issues/45631
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45630
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45629
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45627
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45626
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45625
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45623
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45622
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45621
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45618
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45617
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45616
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45615
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45614
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45612
#
# ...

# %%
js1=pd.DataFrame(js)

# %%
js1.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
js1.to_csv('json.csv')

# %%
pd.read_csv('json.csv').head(2)
# Out:
#    Unnamed: 0                                                url  \
# 0           0  https://api.github.com/repos/pandas-dev/pandas...
# 1           1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                             html_url          id  \
# ...

# %%
for i in js:
    print(i['user']['login'], end="")
    print("\n")
# Out:
# meeseeksmachine
#
# RehanSD
#
# ntjess
#
# mroeschke
#
# jbrockmendel
#
# NumberPiOso
#
# phofl
#
# jbrockmendel
#
# ketozhang
#
# jsignell
#
# Archer6621
#
# Robbie-Palmer
#
# Robbie-Palmer
#
# KayvanShah1
#
# mroeschke
#
# henryiii
#
# twoertwein
#
# lukemanley
#
# batterseapower
#
# normanius
#
# mroeschke
#
# yinweisu
#
# wkerzendorf
#
# treiher
#
# f4kt
#
# jbrockmendel
#
# aulemahal
#
# zkrolikowski-vl
#
# zkrolikowski-vl
#
# QubinX

# %%
l = []
for i in js:
    l.append(i['user'])
pd.DataFrame(l)
# Out:
#               login        id               node_id  \
# 0   meeseeksmachine  39504233  MDQ6VXNlcjM5NTA0MjMz
# 1           RehanSD  17012605  MDQ6VXNlcjE3MDEyNjA1
# 2            ntjess  23620506  MDQ6VXNlcjIzNjIwNTA2
# 3         mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 4      jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 5       NumberPiOso  46936498  MDQ6VXNlcjQ2OTM2NDk4
# 6             phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 7      jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 8         ketozhang  13506487  MDQ6VXNlcjEzNTA2NDg3
# 9          jsignell   4806877  MDQ6VXNlcjQ4MDY4Nzc=
# 10       Archer6621   6449766  MDQ6VXNlcjY0NDk3NjY=
# 11    Robbie-Palmer   8760191  MDQ6VXNlcjg3NjAxOTE=
# 12    Robbie-Palmer   8760191  MDQ6VXNlcjg3NjAxOTE=
# 13      KayvanShah1  59110083  MDQ6VXNlcjU5MTEwMDgz
# 14        mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 15         henryiii   4616906  MDQ6VXNlcjQ2MTY5MDY=
# 16       twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
# ...

# %%
json_data = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
data = pd.DataFrame.from_records(json_data['user'])
data
# Out:
#               login        id               node_id  \
# 0   meeseeksmachine  39504233  MDQ6VXNlcjM5NTA0MjMz
# 1           RehanSD  17012605  MDQ6VXNlcjE3MDEyNjA1
# 2            ntjess  23620506  MDQ6VXNlcjIzNjIwNTA2
# 3         mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 4      jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 5       NumberPiOso  46936498  MDQ6VXNlcjQ2OTM2NDk4
# 6             phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 7      jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 8         ketozhang  13506487  MDQ6VXNlcjEzNTA2NDg3
# 9          jsignell   4806877  MDQ6VXNlcjQ4MDY4Nzc=
# 10       Archer6621   6449766  MDQ6VXNlcjY0NDk3NjY=
# 11    Robbie-Palmer   8760191  MDQ6VXNlcjg3NjAxOTE=
# 12    Robbie-Palmer   8760191  MDQ6VXNlcjg3NjAxOTE=
# 13      KayvanShah1  59110083  MDQ6VXNlcjU5MTEwMDgz
# 14        mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 15         henryiii   4616906  MDQ6VXNlcjQ2MTY5MDY=
# 16       twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
# ...
