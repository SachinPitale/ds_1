# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[df['Fare'] == max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes.values
# Out:
# array([dtype('int64'), dtype('int64'), dtype('int64'), dtype('O'),
#        dtype('O'), dtype('float64'), dtype('int64'), dtype('int64'),
#        dtype('O'), dtype('float64'), dtype('O'), dtype('O')], dtype=object)

# %%
dy = df.dtypes

# %%
dy
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dy[0]
# Out:
# dtype('int64')

# %%
dy['Fare']
# Out:
# dtype('float64')

# %%
dy[0:4]
# Out:
# PassengerId     int64
# Survived        int64
# Pclass          int64
# Name           object
# dtype: object

# %%
df['Age'][10:100]
# Out:
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
#       ...
# 95     NaN
# 96    71.0
# 97    23.0
# 98    34.0
# 99    34.0
# Name: Age, Length: 90, dtype: float64

# %%
df['Age'][100:10:-1]
# Out:
# 100    28.0
# 99     34.0
# 98     34.0
# 97     23.0
# 96     71.0
#        ...
# 15     55.0
# 14     14.0
# 13     39.0
# 12     20.0
# 11     58.0
# Name: Age, Length: 90, dtype: float64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes[df.dtypes  == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes  == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes  == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
dfca=df[df.dtypes[df.dtypes  == 'object'].index]

# %%
dfca.describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Age','Fare']]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
import numpy as np

# %%
np.where(df['Age'].isnull() == True)
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
for i in np.where(df['Age'].isnull() == True):
    print(len(i))
# Out:
# 177

# %%
df[df['Age'].isnull() == True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
Age_null_data=np.where(df['Age'].isnull() == True)

# %%
Age_null_data
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
# To fetch the row data by above indexs

# %%
# iloc is function in which we pass integer or index location,
df.iloc[Age_null_data]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.iloc[[5]]
# Out:
#    PassengerId  Survived  Pclass              Name   Sex  Age  SibSp  Parch  \
# 5            6         0       3  Moran, Mr. James  male  NaN      0      0
#
#    Ticket    Fare Cabin Embarked
# 5  330877  8.4583   NaN        Q

# %%
df.iloc[[1,2,3,4,5,7,28]]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 7             8         0       3
# 28           29         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
#
#     Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.iloc[100:200]
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 100          101         0       3                 Petranec, Miss. Matilda
# 101          102         0       3        Petroff, Mr. Pastcho ("Pentcho")
# 102          103         0       1               White, Mr. Richard Frasar
# 103          104         0       3              Johansson, Mr. Gustaf Joel
# 104          105         0       3          Gustafsson, Mr. Anders Vilhelm
# ..           ...       ...     ...                                     ...
# 195          196         1       1                    Lurette, Miss. Elise
# 196          197         0       3                     Mernagh, Mr. Robert
# 197          198         0       3        Olsen, Mr. Karl Siegwart Andreas
# 198          199         1       3        Madigan, Miss. Margaret "Maggie"
# 199          200         0       2  Yrois, Miss. Henriette ("Mrs Harbeck")
#
#         Sex   Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# ...

# %%
df['Fare'][df['Fare'] == max(df['Fare'])]
# Out:
# 258    512.3292
# 679    512.3292
# 737    512.3292
# Name: Fare, dtype: float64

# %%
# find the person who paid highest fare

# %%
df[df['Fare'] == max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
np.where(df['Fare'] == max(df['Fare']))
# Out:
# (array([258, 679, 737], dtype=int64),)

# %%
df.iloc[np.where(df['Fare'] == max(df['Fare']))]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
df.iloc[np.where(df['Fare'] == max(df['Fare']))]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df[df['Fare']==df['Fare'].max()]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
# find out the name of person who has min age
df.iloc[np.where(df['Age'] == min(df['Age']))]['Name']
# Out:
# 803    Thomas, Master. Assad Alexander
# Name: Name, dtype: object

# %%
# find out the name of person who has age 3
df.iloc[np.where(df['Age']==24.0)]['Name']
# Out:
# 89                                Celotti, Mr. Francesco
# 118                             Baxter, Mr. Quigg Edmond
# 127                            Madsen, Mr. Fridtjof Arne
# 139                                   Giglio, Mr. Victor
# 142    Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...
# 199               Yrois, Miss. Henriette ("Mrs Harbeck")
# 210                                       Ali, Mr. Ahmed
# 234                    Leyson, Mr. Robert William Norman
# 247                      Hamalainen, Mrs. William (Anna)
# 293                                  Haas, Miss. Aloisia
# 294                                     Mineff, Mr. Ivan
# 310                       Hays, Miss. Margaret Bechstein
# 316                  Kantor, Mrs. Sinai (Miriam Sternin)
# 341                       Fortune, Miss. Alice Elizabeth
# 345                        Brown, Miss. Amelia "Mildred"
# 369                        Aubart, Mme. Leontine Pauline
# ...

# %%
np.where(df['Age']== 24.0)
# Out:
# (array([ 89, 118, 127, 139, 142, 199, 210, 234, 247, 293, 294, 310, 316,
#         341, 345, 369, 394, 437, 499, 514, 565, 600, 615, 641, 655, 710,
#         743, 770, 858, 864], dtype=int64),)

# %%
df.iloc[np.where(df['Age'] == 24.0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 89            90         0       3
# 118          119         0       1
# 127          128         1       3
# 139          140         0       1
# 142          143         1       3
# 199          200         0       2
# 210          211         0       3
# 234          235         0       2
# 247          248         1       2
# 293          294         0       3
# 294          295         0       3
# 310          311         1       1
# 316          317         1       2
# 341          342         1       1
# 345          346         1       2
# 369          370         1       1
# 394          395         1       3
# 437          438         1       2
# 499          500         0       3
# 514          515         0       3
# 565          566         0       3
# 600          601         1       2
# 615          616         1       2
# 641          642         1       1
# 655          656         0       2
# ...

# %%
# find the maxinum age of person
df.iloc[np.where(df['Age'] == max(df['Age']))]['Name']
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# person age is cabin in Nan

# %%
df.iloc[np.where(df['Cabin'].isnull() == True)]['Age']
# Out:
# 0      22.0
# 2      26.0
# 4      35.0
# 5       NaN
# 7       2.0
#        ...
# 884    25.0
# 885    39.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: Age, Length: 687, dtype: float64

# %%
df.iloc[df['Cabin'][df['Cabin'].isnull()].index]['Age']
# Out:
# 0      22.0
# 2      26.0
# 4      35.0
# 5       NaN
# 7       2.0
#        ...
# 884    25.0
# 885    39.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: Age, Length: 687, dtype: float64

# %%
df[df['Cabin'].isnull()]['Age']

# %%
# find the male passenger name who's survived is 1

# %%
df.iloc[np.where(df['Survived'] == 1)][df['Sex'] == 'male'][['Name']]
# Out:
# C:\Users\Delll\AppData\Local\Temp/ipykernel_10476/3770831079.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.iloc[np.where(df['Survived'] == 1)][df['Sex'] == 'male'][['Name']]
#                                 Name
# 17      Williams, Mr. Charles Eugene
# 21             Beesley, Mr. Lawrence
# 23      Sloper, Mr. William Thompson
# 36                  Mamee, Mr. Hanna
# 55                 Woolner, Mr. Hugh
# ..                               ...
# 838                  Chip, Mr. Chang
# 839             Marechal, Mr. Pierre
# 857           Daly, Mr. Peter Denis
# 869  Johnson, Master. Harold Theodor
# 889            Behr, Mr. Karl Howell
#
# [109 rows x 1 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.iloc[np.where(df['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[np.where(df['Survived'] == 1)][df['Sex'] == 'male']['Name']
# Out:
# C:\Users\Delll\AppData\Local\Temp/ipykernel_10476/3394148284.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.iloc[np.where(df['Survived'] == 1)][df['Sex'] == 'male']['Name']
# 17        Williams, Mr. Charles Eugene
# 21               Beesley, Mr. Lawrence
# 23        Sloper, Mr. William Thompson
# 36                    Mamee, Mr. Hanna
# 55                   Woolner, Mr. Hugh
#                     ...
# 838                    Chip, Mr. Chang
# 839               Marechal, Mr. Pierre
# 857             Daly, Mr. Peter Denis
# 869    Johnson, Master. Harold Theodor
# 889              Behr, Mr. Karl Howell
# Name: Name, Length: 109, dtype: object

# %%
df.Name[(df['Survived'] == 1) & (df['Sex'] == 'male')]
# Out:
# 17        Williams, Mr. Charles Eugene
# 21               Beesley, Mr. Lawrence
# 23        Sloper, Mr. William Thompson
# 36                    Mamee, Mr. Hanna
# 55                   Woolner, Mr. Hugh
#                     ...
# 838                    Chip, Mr. Chang
# 839               Marechal, Mr. Pierre
# 857             Daly, Mr. Peter Denis
# 869    Johnson, Master. Harold Theodor
# 889              Behr, Mr. Karl Howell
# Name: Name, Length: 109, dtype: object

# %%
df[(df['Survived'] == 1) & (df['Sex'] == 'male')]['Name']
# Out:
# 17        Williams, Mr. Charles Eugene
# 21               Beesley, Mr. Lawrence
# 23        Sloper, Mr. William Thompson
# 36                    Mamee, Mr. Hanna
# 55                   Woolner, Mr. Hugh
#                     ...
# 838                    Chip, Mr. Chang
# 839               Marechal, Mr. Pierre
# 857             Daly, Mr. Peter Denis
# 869    Johnson, Master. Harold Theodor
# 889              Behr, Mr. Karl Howell
# Name: Name, Length: 109, dtype: object

# %%
df['new_col'] = 'sachin'

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# convert list to series

# %%
l = [1,2,3,4,5]

# %%
pd.Series(l)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# convert Dict to series

# %%
d = {'key': "sachin", "title" : "Pitale" , "mail_id" : "abc@abc.com"}

# %%
d
# Out:
# {'key': 'sachin', 'title': 'Pitale', 'mail_id': 'abc@abc.com'}

# %%
pd.DataFrame(d,index=['key','title', 'mail_id'])
# Out:
#             key   title      mail_id
# key      sachin  Pitale  abc@abc.com
# title    sachin  Pitale  abc@abc.com
# mail_id  sachin  Pitale  abc@abc.com

# %%
pd.Series(d)
# Out:
# key             sachin
# title           Pitale
# mail_id    abc@abc.com
# dtype: object

# %%
import numpy as np

# %%
np.random.randn(3,4)
# Out:
# array([[ 0.26363292, -1.90375418, -2.75590076, -0.48378633],
#        [ 2.29340248,  0.20374972, -1.40420015, -1.1033559 ],
#        [-0.50086665, -0.09570352, -0.26032112, -0.98193787]])

# %%
arr = np.random.randn(3,4)

# %%
pd.DataFrame(arr)
# Out:
#           0         1         2         3
# 0 -0.182179  0.658942 -0.167469 -0.996145
# 1  1.251877  1.288608 -1.206458  0.919537
# 2  0.397347 -0.754455 -1.489326  0.181870

# %%
pd.Series(arr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3052/2396573727.py in <module>
# ----> 1 pd.Series(arr)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     437                     data = data.copy()
#     438             else:
# --> 439                 data = sanitize_array(data, index, dtype, copy)
#     440
#     441                 manager = get_option("mode.data_manager")
#
# ~\anaconda3\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     574                 subarr = maybe_infer_to_datetimelike(subarr)
#     575
# --> 576     subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     577
#     578     if isinstance(subarr, np.ndarray):
#
# ...

# %%
 pd.Series(np.array([1,2,3,4,5]))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
 srr =pd.Series(np.array([1,2,3,4,5]), index=['a','b','c','d','e'])

# %%
srr
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int32

# %%
srr['e']
# Out:
# 5

# %%
srr.iloc['e']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3052/2630475887.py in <module>
# ----> 1 srr.iloc['e']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1561             key = item_from_zerodim(key)
#    1562             if not is_integer(key):
# -> 1563                 raise TypeError("Cannot index by location index with a non-integer key")
#    1564
#    1565             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
srr.loc['e'] # access data by name object
# Out:
# 5

# %%
 srr1 =pd.Series(np.array([1,2,3,4,5]), index=[11,12,13,14,15])

# %%
srr1
# Out:
# 11    1
# 12    2
# 13    3
# 14    4
# 15    5
# dtype: int32

# %%
srr1.loc[14]
# Out:
# 4

# %%
# iloc : it always work with defult index value
# loc : it used for object and user defined index value

# %%
np.random.randint(3,6, (4,5))
# Out:
# array([[4, 4, 3, 4, 5],
#        [4, 3, 3, 4, 3],
#        [5, 5, 4, 4, 3],
#        [5, 3, 3, 5, 5]])

# %%
pd.DataFrame(np.random.randint(3,6, (4,5)))
# Out:
#    0  1  2  3  4
# 0  5  3  5  4  4
# 1  3  4  5  3  3
# 2  3  3  4  3  3
# 3  5  5  5  4  3

# %%
df1=pd.DataFrame(np.random.randint(3,6, (4,5)), index=['a','b','c','d'], columns=['x','y','z','u','v'])

# %%
df1
# Out:
#    x  y  z  u  v
# a  5  3  3  4  5
# b  5  4  4  4  4
# c  4  5  4  4  3
# d  5  3  5  5  3

# %%
df1['c'[]:'z']
# Out:
#    x  y  z  u  v
# c  4  5  4  4  3
# d  5  3  5  5  3

# %%
df1.loc[["c","d"],["z","u"]]
# Out:
#    z  u
# c  4  4
# d  5  5

# %%
df1
# Out:
#    x  y  z  u  v
# a  5  3  3  4  5
# b  5  4  4  4  4
# c  4  5  4  4  3
# d  5  3  5  5  3

# %%
df1['new'] = df1['x'] + df1['y']

# %%
df1
# Out:
#    x  y  z  u  v  new
# a  5  3  3  4  5    8
# b  5  4  4  4  4    9
# c  4  5  4  4  3    9
# d  5  3  5  5  3    8

# %%
# drop the column

# %%
df1.drop('x') # default value of axis is 0, means it will check x at x axis it would be row, for column always use axis =1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3052/4023144220.py in <module>
# ----> 1 df1.drop('x')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
df1.drop('x', axis=1)
# Out:
#    y  z  u  v  new
# a  3  3  4  5    8
# b  4  4  4  4    9
# c  5  4  4  3    9
# d  3  5  5  3    8

# %%
df1
# Out:
#    x  y  z  u  v  new
# a  5  3  3  4  5    8
# b  5  4  4  4  4    9
# c  4  5  4  4  3    9
# d  5  3  5  5  3    8

# %%
# To make parment use inplace=True

# %%
df1.drop('x', axis=1, inplace=True)

# %%
df1
# Out:
#    y  z  u  v  new
# a  3  3  4  5    8
# b  4  4  4  4    9
# c  5  4  4  3    9
# d  3  5  5  3    8

# %%
import pandas as pd

# %%
import numpy as np

# %%
np.random.rand(4,5)
# Out:
# array([[0.34150192, 0.37505026, 0.75713837, 0.45001368, 0.87818815],
#        [0.75908985, 0.49362116, 0.80359108, 0.9571445 , 0.80221333],
#        [0.25865132, 0.47554025, 0.45776544, 0.05626477, 0.93427283],
#        [0.92568034, 0.20675096, 0.31264059, 0.585875  , 0.31519006]])

# %%
np.random.seed(23)
df = pd.DataFrame(np.random.randn(4,5),index=['a','b','c','d'], columns=['x','y','z','u','v'])

# %%
df
# Out:
#           x         y         z         u         v
# a  0.666988  0.025813 -0.777619  0.948634  0.701672
# b -1.051082 -0.367548 -1.137460 -1.322148  1.772258
# c -0.347459  0.670140  0.322272  0.060343 -1.043450
# d -1.009942  0.441736  1.128877 -1.838068 -0.938769

# %%
# find out all the negetive values
df[(df<0)]
# Out:
#           x         y         z         u         v
# a       NaN       NaN -0.777619       NaN       NaN
# b -1.051082 -0.367548 -1.137460 -1.322148       NaN
# c -0.347459       NaN       NaN       NaN -1.043450
# d -1.009942       NaN       NaN -1.838068 -0.938769

# %%
df.values[df.values<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
pd.DataFrame(df.values[df.iloc[0:5] <0])
# Out:
#           0
# 0 -0.777619
# 1 -1.051082
# 2 -0.367548
# 3 -1.137460
# 4 -1.322148
# 5 -0.347459
# 6 -1.043450
# 7 -1.009942
# 8 -1.838068
# 9 -0.938769

# %%
df.values[df.iloc[0:5] <0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
l = df.values[df<0]

# %%
l
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
for c in df.columns:
    for v in df.index:
        if df[c][v] in l:
            print(c,v,df[c][v])
# Out:
# x b -1.0510815639071178
# x c -0.34745899102186334
# x d -1.0099418765878465
# y b -0.3675481161171661
# z a -0.7776194131918178
# z b -1.1374596907250272
# u b -1.3221475225908594
# u d -1.8380677677579502
# v c -1.0434500017467254
# v d -0.9387686311201282

# %%
df.columns
# Out:
# Index(['x', 'y', 'z', 'u', 'v'], dtype='object')

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.values[df.values<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
for i in df.columns:
    for j in df.index:
        for k in df.values[df.values<0]:
            print(k,(i,j) )
# Out:
# -0.7776194131918178 ('x', 'a')
# -1.0510815639071178 ('x', 'a')
# -0.3675481161171661 ('x', 'a')
# -1.1374596907250272 ('x', 'a')
# -1.3221475225908594 ('x', 'a')
# -0.34745899102186334 ('x', 'a')
# -1.0434500017467254 ('x', 'a')
# -1.0099418765878465 ('x', 'a')
# -1.8380677677579502 ('x', 'a')
# -0.9387686311201282 ('x', 'a')
# -0.7776194131918178 ('x', 'b')
# -1.0510815639071178 ('x', 'b')
# -0.3675481161171661 ('x', 'b')
# -1.1374596907250272 ('x', 'b')
# -1.3221475225908594 ('x', 'b')
# -0.34745899102186334 ('x', 'b')
# -1.0434500017467254 ('x', 'b')
# -1.0099418765878465 ('x', 'b')
# -1.8380677677579502 ('x', 'b')
# -0.9387686311201282 ('x', 'b')
# -0.7776194131918178 ('x', 'c')
# -1.0510815639071178 ('x', 'c')
# -0.3675481161171661 ('x', 'c')
# -1.1374596907250272 ('x', 'c')
# -1.3221475225908594 ('x', 'c')
# -0.34745899102186334 ('x', 'c')
# -1.0434500017467254 ('x', 'c')
# -1.0099418765878465 ('x', 'c')
# -1.8380677677579502 ('x', 'c')
# -0.9387686311201282 ('x', 'c')
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3404/1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.loc['a','y']

# %%
import numpy as np

# %%
d = {'key1': [1,2,3,4,np.nan],"key2": ["sachin","pit",np.nan,5,6],'key3': [np.nan,np.nan,np.nan,8,9]}

# %%
df =pd.DataFrame(d)

# %%
df
# Out:
#    key1    key2  key3
# 0   1.0  sachin   NaN
# 1   2.0     pit   NaN
# 2   3.0     NaN   NaN
# 3   4.0       5   8.0
# 4   NaN       6   9.0

# %%
df.dropna() # it will drop all the row which contain NaN
# Out:
#    key1 key2  key3
# 3   4.0    5   8.0

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df.dropna(thresh=0) # thresh look zeror nan value , if zero non nan value found it would delete
# Out:
#    key1    key2  key3
# 0   1.0  sachin   NaN
# 1   2.0     pit   NaN
# 2   3.0     NaN   NaN
# 3   4.0       5   8.0
# 4   NaN       6   9.0

# %%
df.dropna(thresh=1) #It will delete if did not find single non na value
# Out:
#    key1    key2  key3
# 0   1.0  sachin   NaN
# 1   2.0     pit   NaN
# 2   3.0     NaN   NaN
# 3   4.0       5   8.0
# 4   NaN       6   9.0

# %%
df.dropna(thresh=2) #It will delete if did not find two non na value
# Out:
#    key1    key2  key3
# 0   1.0  sachin   NaN
# 1   2.0     pit   NaN
# 3   4.0       5   8.0
# 4   NaN       6   9.0

# %%
df.dropna(thresh=3)
# Out:
#    key1 key2  key3
# 3   4.0    5   8.0

# %%
df.dropna(thresh=4)
# Out:
# Empty DataFrame
# Columns: [key1, key2, key3]
# Index: []

# %%
df
# Out:
#    key1    key2  key3
# 0   1.0  sachin   NaN
# 1   2.0     pit   NaN
# 2   3.0     NaN   NaN
# 3   4.0       5   8.0
# 4   NaN       6   9.0

# %%
df.dropna(axis=1,thresh=3)
# Out:
#    key1    key2
# 0   1.0  sachin
# 1   2.0     pit
# 2   3.0     NaN
# 3   4.0       5
# 4   NaN       6

# %%
# replace nan value

# %%
df
# Out:
#    key1    key2  key3
# 0   1.0  sachin   NaN
# 1   2.0     pit   NaN
# 2   3.0     NaN   NaN
# 3   4.0       5   8.0
# 4   NaN       6   9.0

# %%
df.fillna("DS")
# Out:
#   key1    key2 key3
# 0  1.0  sachin   DS
# 1  2.0     pit   DS
# 2  3.0      DS   DS
# 3  4.0       5  8.0
# 4   DS       6  9.0

# %%
df.fillna(567)
# Out:
#     key1    key2   key3
# 0    1.0  sachin  567.0
# 1    2.0     pit  567.0
# 2    3.0     567  567.0
# 3    4.0       5    8.0
# 4  567.0       6    9.0

# %%
df.fillna(value=df['key1'].mean())
# Out:
#    key1    key2  key3
# 0   1.0  sachin   2.5
# 1   2.0     pit   2.5
# 2   3.0     2.5   2.5
# 3   4.0       5   8.0
# 4   2.5       6   9.0

# %%
df['key1'].mean()
# Out:
# 2.5

# %%
df['key3'].mean()
# Out:
# 8.5

# %%
df
# Out:
#    key1    key2  key3
# 0   1.0  sachin   NaN
# 1   2.0     pit   NaN
# 2   3.0     NaN   NaN
# 3   4.0       5   8.0
# 4   NaN       6   9.0

# %%
d = {'key1': ['sachin','pitale',sachinpitale@ga.com,123],"key2": ["sachin","pitale",z,5,6],'key3': [np.nan,np.nan,np.nan,8,9]}

# %%
d1 = {'name': ['sudh','visal','umang','vishal','umang'], 'mail_id' : ['sudh@gmail.com','visal@gmail.com','umang@gmail.com','vishal@gmail.com','umang@gmail.com'], 'salary':[100,200,500,200,500] }

# %%
d1
# Out:
# {'name': ['sudh', 'visal', 'umang', 'vishal', 'umang'],
#  'mail_id': ['sudh@gmail.com',
#   'visal@gmail.com',
#   'umang@gmail.com',
#   'vishal@gmail.com',
#   'umang@gmail.com'],
#  'salary': [100, 200, 500, 200, 500]}

# %%
df = pd.DataFrame(d1)

# %%
df
# Out:
#      name           mail_id  salary
# 0    sudh    sudh@gmail.com     100
# 1   visal   visal@gmail.com     200
# 2   umang   umang@gmail.com     500
# 3  vishal  vishal@gmail.com     200
# 4   umang   umang@gmail.com     500

# %%
df.groupby('name').mean()
# Out:
#         salary
# name
# sudh     100.0
# umang    500.0
# visal    200.0
# vishal   200.0

# %%
df.groupby('mail_id').mean()
# Out:
#                   salary
# mail_id
# sudh@gmail.com     100.0
# umang@gmail.com    500.0
# visal@gmail.com    200.0
# vishal@gmail.com   200.0

# %%
df.groupby('mail_id').sum()
# Out:
#                   salary
# mail_id
# sudh@gmail.com       100
# umang@gmail.com     1000
# visal@gmail.com      200
# vishal@gmail.com     200

# %%
df.groupby('mail_id').describe()
# Out:
#                  salary
#                   count   mean  std    min    25%    50%    75%    max
# mail_id
# sudh@gmail.com      1.0  100.0  NaN  100.0  100.0  100.0  100.0  100.0
# umang@gmail.com     2.0  500.0  0.0  500.0  500.0  500.0  500.0  500.0
# visal@gmail.com     1.0  200.0  NaN  200.0  200.0  200.0  200.0  200.0
# vishal@gmail.com    1.0  200.0  NaN  200.0  200.0  200.0  200.0  200.0

# %%
type(df.groupby('mail_id').describe())
# Out:
# pandas.core.frame.DataFrame

# %%
df.groupby('mail_id').describe().loc['umang@gmail.com']
# Out:
# salary  count      2.0
#         mean     500.0
#         std        0.0
#         min      500.0
#         25%      500.0
#         50%      500.0
#         75%      500.0
#         max      500.0
# Name: umang@gmail.com, dtype: float64

# %%
df.groupby('mail_id').describe().loc['umang@gmail.com']['salary']['mean']
# Out:
# 500.0

# %%
df.groupby('mail_id').describe().loc['umang@gmail.com'][1]
# Out:
# 500.0

# %%
df.groupby('mail_id').describe()
# Out:
#                  salary
#                   count   mean  std    min    25%    50%    75%    max
# mail_id
# sudh@gmail.com      1.0  100.0  NaN  100.0  100.0  100.0  100.0  100.0
# umang@gmail.com     2.0  500.0  0.0  500.0  500.0  500.0  500.0  500.0
# visal@gmail.com     1.0  200.0  NaN  200.0  200.0  200.0  200.0  200.0
# vishal@gmail.com    1.0  200.0  NaN  200.0  200.0  200.0  200.0  200.0

# %%
# convert row -> coloumn and coloumn -> row

# %%
df.groupby('mail_id').describe().T  # T transform function
# Out:
# mail_id       sudh@gmail.com  umang@gmail.com  visal@gmail.com  \
# salary count             1.0              2.0              1.0
#        mean            100.0            500.0            200.0
#        std               NaN              0.0              NaN
#        min             100.0            500.0            200.0
#        25%             100.0            500.0            200.0
#        50%             100.0            500.0            200.0
#        75%             100.0            500.0            200.0
#        max             100.0            500.0            200.0
#
# mail_id       vishal@gmail.com
# salary count               1.0
#        mean              200.0
#        std                 NaN
#        min               200.0
#        25%               200.0
#        50%               200.0
#        75%               200.0
#        max               200.0

# %%
import numpy as np

# %%
arr1 = np.random.randn(3,4)

# %%
arr2 = np.random.randn(3,4)

# %%
arr3 = np.random.randn(3,4)

# %%
df1 = pd.DataFrame(arr1,columns=["A","B","C","D"], index=[0,1,2])

# %%
df2 = pd.DataFrame(arr2,columns=["A","B","C","D"], index=[3,4,5])

# %%
df2
# Out:
#           A         B         C         D
# 3  0.991030  1.511421  0.916045  0.713294
# 4  0.077568  0.093318  0.399625 -1.314135
# 5 -1.097323 -0.051319  0.186657 -0.655285

# %%
df3 = pd.DataFrame(arr3,columns=["A","B","C","D"], index=[6,7,8])

# %%
df3
# Out:
#           A         B         C         D
# 6 -1.543097 -0.954023 -2.762539 -0.315635
# 7  0.797414  1.098826  1.191656 -0.294175
# 8  1.976797 -1.431395 -1.646384  2.217287

# %%
# vertically concatinate the 3 tables

# %%
pd.concat([df1,df2,df3])
# Out:
#           A         B         C         D
# 0  0.882182 -1.019025 -0.069806  1.830465
# 1 -0.000389 -0.117277  0.915728  0.058334
# 2 -1.020750  0.501800 -0.525912  0.006714
# 0  0.991030  1.511421  0.916045  0.713294
# 1  0.077568  0.093318  0.399625 -1.314135
# 2 -1.097323 -0.051319  0.186657 -0.655285
# 0 -1.543097 -0.954023 -2.762539 -0.315635
# 1  0.797414  1.098826  1.191656 -0.294175
# 2  1.976797 -1.431395 -1.646384  2.217287

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#           A         B         C         D         A         B         C  \
# 0  0.882182 -1.019025 -0.069806  1.830465  0.991030  1.511421  0.916045
# 1 -0.000389 -0.117277  0.915728  0.058334  0.077568  0.093318  0.399625
# 2 -1.020750  0.501800 -0.525912  0.006714 -1.097323 -0.051319  0.186657
#
#           D         A         B         C         D
# 0  0.713294 -1.543097 -0.954023 -2.762539 -0.315635
# 1 -1.314135  0.797414  1.098826  1.191656 -0.294175
# 2 -0.655285  1.976797 -1.431395 -1.646384  2.217287

# %%
df4 = pd.concat([df1,df2,df3])

# %%
df4.iloc[0]
# Out:
# A    0.882182
# B   -1.019025
# C   -0.069806
# D    1.830465
# Name: 0, dtype: float64

# %%
df4.loc[0]
# Out:
#           A         B         C         D
# 0  0.882182 -1.019025 -0.069806  1.830465
# 0  0.991030  1.511421  0.916045  0.713294
# 0 -1.543097 -0.954023 -2.762539 -0.315635

# %%
df5 = pd.concat([df1,df2,df3],axis=1)

# %%
df5
# Out:
#           A         B         C         D         A         B         C  \
# 0  0.882182 -1.019025 -0.069806  1.830465  0.991030  1.511421  0.916045
# 1 -0.000389 -0.117277  0.915728  0.058334  0.077568  0.093318  0.399625
# 2 -1.020750  0.501800 -0.525912  0.006714 -1.097323 -0.051319  0.186657
#
#           D         A         B         C         D
# 0  0.713294 -1.543097 -0.954023 -2.762539 -0.315635
# 1 -1.314135  0.797414  1.098826  1.191656 -0.294175
# 2 -0.655285  1.976797 -1.431395 -1.646384  2.217287

# %%
df5['A']
# Out:
#           A         A         A
# 0  0.882182  0.991030 -1.543097
# 1 -0.000389  0.077568  0.797414
# 2 -1.020750 -1.097323  1.976797

# %%
df5.iloc[:,4]
# Out:
# 0    0.991030
# 1    0.077568
# 2   -1.097323
# Name: A, dtype: float64

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#           A         B         C         D         A         B         C  \
# 0  0.882182 -1.019025 -0.069806  1.830465       NaN       NaN       NaN
# 1 -0.000389 -0.117277  0.915728  0.058334       NaN       NaN       NaN
# 2 -1.020750  0.501800 -0.525912  0.006714       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN  0.991030  1.511421  0.916045
# 4       NaN       NaN       NaN       NaN  0.077568  0.093318  0.399625
# 5       NaN       NaN       NaN       NaN -1.097323 -0.051319  0.186657
# 6       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           D         A         B         C         D
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# ...

# %%
pd.concat([df1,df2,df3],axis=1).fillna(0)
# Out:
#           A         B         C         D         A         B         C  \
# 0  0.882182 -1.019025 -0.069806  1.830465  0.000000  0.000000  0.000000
# 1 -0.000389 -0.117277  0.915728  0.058334  0.000000  0.000000  0.000000
# 2 -1.020750  0.501800 -0.525912  0.006714  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.991030  1.511421  0.916045
# 4  0.000000  0.000000  0.000000  0.000000  0.077568  0.093318  0.399625
# 5  0.000000  0.000000  0.000000  0.000000 -1.097323 -0.051319  0.186657
# 6  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#           D         A         B         C         D
# 0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
df1
# Out:
#           A         B         C         D
# 0  0.882182 -1.019025 -0.069806  1.830465
# 1 -0.000389 -0.117277  0.915728  0.058334
# 2 -1.020750  0.501800 -0.525912  0.006714

# %%
df2
# Out:
#           A         B         C         D
# 3  0.991030  1.511421  0.916045  0.713294
# 4  0.077568  0.093318  0.399625 -1.314135
# 5 -1.097323 -0.051319  0.186657 -0.655285

# %%
np.random.seed(23)
arr1 = np.random.randn(3,4)
np.random.seed(23)
arr2 = np.random.randn(3,4)
df11 = pd.DataFrame(arr1,columns=["A","B","C","D"], index=[0,1,2])
df22 = pd.DataFrame(arr2,columns=["A","B","C","D"], index=[0,1,2])

# %%
df11
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140

# %%
df22
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140

# %%
pd.merge(df11,df21, on='A')
# Out:
#           A       B_x       C_x       D_x       B_y       C_y       D_y
# 0  0.666988  0.025813 -0.777619  0.948634  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140  1.772258 -0.347459  0.670140

# %%
left = pd.DataFrame({'key' : ['k0','k8','k2','k3'], 'A' : ['A0', 'A1', 'A2','A3'], 'B': ['B0','B1', 'B2','B3']})

# %%
right = pd.DataFrame({'key' : ['k0','k4','k2','k3'], 'C' : ['C0', 'C1', 'C2','C3'], 'D': ['D0','D1', 'D2','D3']})

# %%
left
# Out:
#   key   A   B
# 0  k0  A0  B0
# 1  k8  A1  B1
# 2  k2  A2  B2
# 3  k3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  k0  C0  D0
# 1  k4  C1  D1
# 2  k2  C2  D2
# 3  k3  C3  D3

# %%
pd.merge(left,right,on='key')
# Out:
#   key   A   B   C   D
# 0  k0  A0  B0  C0  D0
# 1  k2  A2  B2  C2  D2
# 2  k3  A3  B3  C3  D3

# %%
pd.merge(left,right,on='key', how='left')
# Out:
#   key   A   B    C    D
# 0  k0  A0  B0   C0   D0
# 1  k8  A1  B1  NaN  NaN
# 2  k2  A2  B2   C2   D2
# 3  k3  A3  B3   C3   D3

# %%
pd.merge(left,right,on='key', how='right')
# Out:
#   key    A    B   C   D
# 0  k0   A0   B0  C0  D0
# 1  k4  NaN  NaN  C1  D1
# 2  k2   A2   B2  C2  D2
# 3  k3   A3   B3  C3  D3

# %%
pd.merge(left,right,on='key', how='outer')
# Out:
#   key    A    B    C    D
# 0  k0   A0   B0   C0   D0
# 1  k8   A1   B1  NaN  NaN
# 2  k2   A2   B2   C2   D2
# 3  k3   A3   B3   C3   D3
# 4  k4  NaN  NaN   C1   D1

# %%
df1 = pd.DataFrame({'key1' : ['k0','k0','k1','k2'], 'key2' : ['k0','k1','k0','k1'],'A' : ['A0', 'A1', 'A2','A3'], 'B': ['B0','B1', 'B2','B3']})
df2 = pd.DataFrame({'key1' : ['k0','k1','k1','k2'], 'key2' : ['k0','k0','k0','k0'], 'C' : ['C0', 'C1', 'C2','C3'], 'D': ['D0','D1', 'D2','D3']})

# %%
df1
# Out:
#   key1 key2   A   B
# 0   k0   k0  A0  B0
# 1   k0   k1  A1  B1
# 2   k1   k0  A2  B2
# 3   k2   k1  A3  B3

# %%
df2
# Out:
#   key1 key2   C   D
# 0   k0   k0  C0  D0
# 1   k1   k0  C1  D1
# 2   k1   k0  C2  D2
# 3   k2   k0  C3  D3

# %%
pd.merge(df1,df2, on = ['key1','key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   k0   k0  A0  B0  C0  D0
# 1   k1   k0  A2  B2  C1  D1
# 2   k1   k0  A2  B2  C2  D2

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1','A2'], 'B': ['B0','B1','B2']}, index=['K0','K1','K2'])

# %%
df2 = pd.DataFrame({'C': ['C0', 'C1','C2'], 'D': ['D0','D1','D2']}, index=['K0','K2','K3'])

# %%
left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right
# Out:
#      C   D
# K0  C0  D0
# K2  C1  D1
# K3  C2  D2

# %%
df1.join(df2)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C1   D1

# %%
df1.join(df2,how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C1   D1
# K3  NaN  NaN   C2   D2
