# %%
import pandas as pd

# %%
df=pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv")

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %%
df.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
df.tail(2)
# Out:
#       order_id  quantity           item_name  \
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
fline = df.head()

# %%
fline
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
fline.to_csv('newdata1.csv')

# %%
pd.read_csv('newdata1.csv')
# Out:
#    Unnamed: 0  order_id  quantity                              item_name  \
# 0           0         1         1           Chips and Fresh Tomato Salsa
# 1           1         1         1                                   Izze
# 2           2         1         1                       Nantucket Nectar
# 3           3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4           4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# %ls
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is EE0B-F929
#
#  Directory of E:\Data Science\DS\04-Pandas\test
#
# 29/01/2022  05:25 PM    <DIR>          .
# 29/01/2022  05:25 PM    <DIR>          ..
# 29/01/2022  05:13 PM    <DIR>          .ipynb_checkpoints
# 29/01/2022  05:25 PM               333 newdata1.csv
# 29/01/2022  05:25 PM            26,159 Untitled.ipynb
#                2 File(s)         26,492 bytes
#                3 Dir(s)  155,496,853,504 bytes free

# %%
df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep="\t")

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep="\t",na_values=['Izze','Chicken Salad Bowl'] )
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                    NaN
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                                    NaN
# 4620      1834         1                                    NaN
# 4621      1834         1                                    NaN
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
df.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df.to_csv('newdata2.csv',index=False,header=False,sep='#')

# %%
df.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %%
df.to_csv('newdata2.csv',columns=['item_name', 'item_price'],index=False)

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df['item_name'].head()
# Out:
# 0             Chips and Fresh Tomato Salsa
# 1                                     Izze
# 2                         Nantucket Nectar
# 3    Chips and Tomatillo-Green Chili Salsa
# 4                             Chicken Bowl
# Name: item_name, dtype: object

# %%
df[['item_name']].head()
# Out:
#                                item_name
# 0           Chips and Fresh Tomato Salsa
# 1                                   Izze
# 2                       Nantucket Nectar
# 3  Chips and Tomatillo-Green Chili Salsa
# 4                           Chicken Bowl

# %%
type(df['item_name'])
# Out:
# pandas.core.series.Series

# %%
df[['item_name','item_price']]
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4617                          Steak Burrito    $11.75
# 4618                          Steak Burrito    $11.75
# 4619                     Chicken Salad Bowl    $11.25
# 4620                     Chicken Salad Bowl     $8.75
# 4621                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 2 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df=pd.read_excel('LUSID.xlsx')

# %%
df
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# ...

# %%
pd.read_excel('LUSID.xlsx', sheet_name="Add your take on balances")
# Out:
#     Unnamed: 0  Unnamed: 1                                         Unnamed: 2  \
# 0          NaN         NaN                                                NaN
# 1          NaN         NaN                                                NaN
# 2          NaN         NaN                                                NaN
# 3          NaN         NaN                                                NaN
# 4          NaN         NaN                                                NaN
# 5          NaN         NaN                                                NaN
# 6          NaN         NaN                                                NaN
# 7          NaN         NaN                                                NaN
# 8          NaN         NaN                                                NaN
# 9          NaN         NaN                                                NaN
# 10         NaN         NaN                                                NaN
# ...

# %%
df=pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")

# %%
df[0]
# Out:
#        Season   Age                                     Tm  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 6

# %%
df[2].to_csv('newdata1.csv',index=False)

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s = """{
"name" : "sachin",
"phone_no" : 393782,
"company" : ["Google","EY", "Microsoft","Amazon","deloitte"]

}
"""

# %%
import json

# %%
s1 = json.loads(s)

# %%
pd.DataFrame(s1)
# Out:
#      name  phone_no    company
# 0  sachin    393782     Google
# 1  sachin    393782         EY
# 2  sachin    393782  Microsoft
# 3  sachin    393782     Amazon
# 4  sachin    393782   deloitte

# %%
pd.DataFrame(s1,columns=['company'])
# Out:
#      company
# 0     Google
# 1         EY
# 2  Microsoft
# 3     Amazon
# 4   deloitte

# %%
import requests

# %%
df = requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")

# %%
df
# Out:
# <Response [200]>

# %%
js=df.json()

# %%
for i in js:
    print(i['url'], end="")
    print('\n')
# Out:
# https://api.github.com/repos/pandas-dev/pandas/issues/45694
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45693
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45692
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45691
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45689
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45688
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45687
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45686
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45684
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45681
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45679
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45678
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45675
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45673
#
# https://api.github.com/repos/pandas-dev/pandas/issues/45672
#
# ...

# %%
js1 = pd.DataFrame(js)

# %%
js1
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js1.to_csv('newdata1.csv')

# %%
for i in js:
    print(i['user']['login'], end=' ')
    print("\n")
# Out:
# galipremsagar
#
# jbrockmendel
#
# mroeschke
#
# jbrockmendel
#
# jbrockmendel
#
# mroeschke
#
# rhshadrach
#
# tehunter
#
# epmojo
#
# philipphu
#
# abowden1989
#
# pdet
#
# pdet
#
# jbrockmendel
#
# jbrockmendel
#
# logannc
#
# jbrockmendel
#
# jonashaag
#
# vincent3717
#
# yakymp
#
# tade0726
#
# dalejung
#
# ben519
#
# jbrockmendel
#
# jonashaag
#
# douglas-raillard-arm
#
# aamster
#
# robertclancy
#
# RehanSD
#
# ntjess
