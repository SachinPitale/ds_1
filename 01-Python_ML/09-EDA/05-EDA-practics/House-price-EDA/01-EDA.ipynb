# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline 

# Display all the columns of the dataframes
pd.pandas.set_option('display.max_columns', None)

# %%
dataset=pd.read_csv('train.csv')

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
# shape of dataset with row and columns
dataset.shape
# Out:
# (1460, 81)

# %%
dataset.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# ## In Data Analysis we will find to below steps
# 1. Missing Values
# 2. All the numerical variables
# 3. Distribution of numerical variables
# 4. Categorical variables
# 5. outliers
# 6. relationship between independent and depended features
# 7. Correlations

# %%
# How to findout missing

# %%
dataset.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
[feature for feature in dataset.columns if dataset[feature].isnull().sum() >= 1]
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
feature_with_na=[feature for feature in dataset.columns if dataset[feature].isnull().sum() >= 1]

# %%
# feature are with nan values
feature_with_na
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
dataset['Fence'].isnull().mean()
# Out:
# 0.8075342465753425

# %%
for feature in feature_with_na:
    print(feature,np.round(dataset[feature].isnull().sum()))
# Out:
# LotFrontage 259
# Alley 1369
# MasVnrType 8
# MasVnrArea 8
# BsmtQual 37
# BsmtCond 37
# BsmtExposure 38
# BsmtFinType1 37
# BsmtFinType2 38
# Electrical 1
# FireplaceQu 690
# GarageType 81
# GarageYrBlt 81
# GarageFinish 81
# GarageQual 81
# GarageCond 81
# PoolQC 1453
# Fence 1179
# MiscFeature 1406

# %%
for feature in feature_with_na:
    print(feature, "=>",np.round(dataset[feature].isnull().mean(), 4), '% misssing values')
# Out:
# LotFrontage => 0.1774 % misssing values
# Alley => 0.9377 % misssing values
# MasVnrType => 0.0055 % misssing values
# MasVnrArea => 0.0055 % misssing values
# BsmtQual => 0.0253 % misssing values
# BsmtCond => 0.0253 % misssing values
# BsmtExposure => 0.026 % misssing values
# BsmtFinType1 => 0.0253 % misssing values
# BsmtFinType2 => 0.026 % misssing values
# Electrical => 0.0007 % misssing values
# FireplaceQu => 0.4726 % misssing values
# GarageType => 0.0555 % misssing values
# GarageYrBlt => 0.0555 % misssing values
# GarageFinish => 0.0555 % misssing values
# GarageQual => 0.0555 % misssing values
# GarageCond => 0.0555 % misssing values
# PoolQC => 0.9952 % misssing values
# Fence => 0.8075 % misssing values
# MiscFeature => 0.963 % misssing values

# %%
for feature in feature_with_na:
    print(feature, "=>",np.round(dataset[feature].isnull().mean()*100, 2), '% misssing values')
# Out:
# LotFrontage => 17.74 % misssing values
# Alley => 93.77 % misssing values
# MasVnrType => 0.55 % misssing values
# MasVnrArea => 0.55 % misssing values
# BsmtQual => 2.53 % misssing values
# BsmtCond => 2.53 % misssing values
# BsmtExposure => 2.6 % misssing values
# BsmtFinType1 => 2.53 % misssing values
# BsmtFinType2 => 2.6 % misssing values
# Electrical => 0.07 % misssing values
# FireplaceQu => 47.26 % misssing values
# GarageType => 5.55 % misssing values
# GarageYrBlt => 5.55 % misssing values
# GarageFinish => 5.55 % misssing values
# GarageQual => 5.55 % misssing values
# GarageCond => 5.55 % misssing values
# PoolQC => 99.52 % misssing values
# Fence => 80.75 % misssing values
# MiscFeature => 96.3 % misssing values

# %%
# find out releationship between all missing columns and target column

# %%
# let's plot some amazing diagram

# %%
data=dataset.copy()
for feature in feature_with_na:
    
    # let's make a variable that indicate 1 if the observation was missing or 0 otherwise
    data[feature]=np.where(data[feature].isnull(),1,0)
    
    # let's calculate the mean saleprice where the information is missing or present
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# Here With the relation between the missing values and the dependent variable is clearly visible.So We need to replace these nan values with something meaningful which we will do in the Feature Engineering section

# %% [markdown]
# # findout the numerical variable

# %%
dataset['Id'].dtypes != 'O'
# Out:
# True

# %%
Numerical_features=[feature for feature in dataset.columns if dataset[feature].dtypes != 'O']

# %%
print(len(Numerical_features))
# Out:
# 38

# %%
dataset[Numerical_features].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %% [markdown]
# ## Temporal Variable(Eg:  Date Time variable)

# %%
year_feature=[feature for feature in Numerical_features if 'Yr' in feature or 'Year' in feature]

# %%
for feature in year_feature:
    print(feature,dataset[feature].unique())
    print ('\n')
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
#
#
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
#
#
# ...

# %%
dataset.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('YearSold')
plt.ylabel('median House price')
plt.title('House price vs year sold')
# Out:
# Text(0.5, 1.0, 'House price vs year sold')

# %%
dataset.groupby('YearBuilt')['SalePrice'].median().plot()
plt.xlabel('YearBuilt ')
plt.ylabel('median House price')
plt.title('YearBuilt  vs year sold')
# Out:
# Text(0.5, 1.0, 'YearBuilt  vs year sold')

# %%
dataset.groupby('YearRemodAdd')['SalePrice'].median().plot()
plt.xlabel('YearRemodAdd')
plt.ylabel('median House price')
plt.title('YearRemodAdd vs year sold')
# Out:
# Text(0.5, 1.0, 'YearRemodAdd vs year sold')

# %%
dataset.groupby('GarageYrBlt')['SalePrice'].median().plot()
plt.xlabel('GarageYrBlt')
plt.ylabel('median House price')
plt.title('GarageYrBlt vs year sold')
# Out:
# Text(0.5, 1.0, 'GarageYrBlt vs year sold')

# %%
### Here we will compare the difference between all years features with Salesprice

# %%
for feature in year_feature:
    if feature != 'YrSold':
        data[feature] = data['YrSold']-data[feature]
        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('sale price')
        plt.show()

# %% [markdown]
# # Observation
# Within all the yearwise information it is cleary visible that the new house are more costlier that the older one. looks like a pareto distribution or power low distribution

# %%
# Numerical variables -2 types
##1. continuous variables and Discrete variable

# %%
discrete_feature=[feature for feature in Numerical_features if len(data[feature].unique())<=25]

# %%
print(len(discrete_feature))
# Out:
# 21

# %%
dataset[discrete_feature].head()
# Out:
#    MSSubClass  LotFrontage  OverallQual  OverallCond  MasVnrArea  \
# 0          60         65.0            7            5       196.0
# 1          20         80.0            6            8         0.0
# 2          60         68.0            7            5       162.0
# 3          70         60.0            7            5         0.0
# 4          60         84.0            8            5       350.0
#
#    LowQualFinSF  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0             0             1             0         2         1             3
# 1             0             0             1         2         0             3
# 2             0             1             0         2         1             3
# 3             0             1             0         1         0             3
# 4             0             1             0         2         1             4
#
#    KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageCars  3SsnPorch  \
# ...

# %%
# find the relationship between Discrete and sales prices

# %%
data=dataset.copy()
for feature in discrete_feature:
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.show()

# %%
## There is a relationship between discreate and sales price

# %% [markdown]
# # continues Variable

# %%
continuous_feature=[feature for feature in Numerical_features if feature not in discrete_feature+year_feature]

# %%
print(len(continuous_feature))
# Out:
# 15

# %%
# let's analyze continuous values by creating histograph to understand distribution values

# %%
data=dataset.copy()
for feature in continuous_feature:
    data.groupby(feature)['SalePrice'].median().plot.hist()
    plt.title(feature)
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.show()

# %%
data=dataset.copy()
for feature in continuous_feature:
    data[feature].hist(bins=25)
    plt.title(feature)
    plt.xlabel(feature)
    plt.ylabel('count')
    plt.show()

# %%
data=dataset.copy()
for feature in discrete_feature:
    data[feature].hist(bins=25)
    plt.title(feature)
    plt.xlabel(feature)
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# ## EDA Part 2

# %%
## Continuous Feature, we will using logagritmic transformation

# %%
data=dataset.copy()
for feature in continuous_feature:
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        plt.scatter(data[feature], data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.title(feature)
        plt.show()

# %% [markdown]
# # outliers

# %%
data=dataset.copy()
for feature in continuous_feature:
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.xlabel(feature)
        plt.show()

# %%
dataset['SalePrice'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.histplot(dataset['SalePrice'],kde=True)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %% [markdown]
# # Catogorical variables

# %%
catogorical_variables=[feature for feature in dataset.columns if dataset[feature].dtypes=='O']

# %%
catogorical_variables
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
print(len(catogorical_variables))
# Out:
# 43

# %%
dataset[catogorical_variables].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
for feature in catogorical_variables:
    print (" The feature name is  {} and the number of catogories are {}".format(feature, len(dataset[feature].unique())) )
# Out:
#  The feature name is  MSZoning and the number of catogories are 5
#  The feature name is  Street and the number of catogories are 2
#  The feature name is  Alley and the number of catogories are 3
#  The feature name is  LotShape and the number of catogories are 4
#  The feature name is  LandContour and the number of catogories are 4
#  The feature name is  Utilities and the number of catogories are 2
#  The feature name is  LotConfig and the number of catogories are 5
#  The feature name is  LandSlope and the number of catogories are 3
#  The feature name is  Neighborhood and the number of catogories are 25
#  The feature name is  Condition1 and the number of catogories are 9
#  The feature name is  Condition2 and the number of catogories are 8
#  The feature name is  BldgType and the number of catogories are 5
#  The feature name is  HouseStyle and the number of catogories are 8
#  The feature name is  RoofStyle and the number of catogories are 6
# ...

# %%
# find the relationship between catogorical feature and salesprice

# %%
data=dataset.copy()
for feature in catogorical_variables:
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title('catogorical feature vs sales prices')
    plt.show()
