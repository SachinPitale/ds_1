# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
flipcart_url="https://www.flipkart.com/search?q="+"iphone"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone'

# %%
uclient=uReq(flipcart_url) #open the flipcark URL

# %%
uclient

# %%
flipkartPage=uclient.read() # It will read html page

# %%
uclient.close() # close the html page

# %%
flipcart_html = bs(flipkartPage, "html.parser") # to read html data

# %%
bigboxes=flipcart_html.find_all("div", {"class": "_1AtVbE col-12-12"})

# %%
len(bigboxes)
# Out:
# 31

# %%
del bigboxes[0:3]

# %%
bigboxes[0]
# Out:
# <div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBFWBYZXSEGBS6F" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/apple-iphone-12-mini-black-64-gb/p/itm38b727191eb08?pid=MOBFWBYZXSEGBS6F&amp;lid=LSTMOBFWBYZXSEGBS6FTONJ6W&amp;marketplace=FLIPKART&amp;q=iphone&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=27ad07be-b73c-4a73-88fa-270998238a05.MOBFWBYZXSEGBS6F.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=gfk0mk2s000000001645853207900&amp;qH=0b3f45b266a97d70" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="APPLE iPhone 12 Mini (Black, 64 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/kg8avm80/mobile/n/p/d/apple-iphone-12-mini-dummyapplefsn-original-imafwgbfwyzztfnh.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class=
# ...

# %%
box=bigboxes[0]

# %%
productLink="https://www.flipkart.com" + box.div.div.div.a['href']

# %%
productLink
# Out:
# 'https://www.flipkart.com/apple-iphone-12-mini-black-64-gb/p/itm38b727191eb08?pid=MOBFWBYZXSEGBS6F&lid=LSTMOBFWBYZXSEGBS6FTONJ6W&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&srno=s_1_1&otracker=search&fm=organic&iid=27ad07be-b73c-4a73-88fa-270998238a05.MOBFWBYZXSEGBS6F.SEARCH&ppt=None&ppn=None&ssid=gfk0mk2s000000001645853207900&qH=0b3f45b266a97d70'

# %%
requests.get(productLink)
# Out:
# <Response [200]>

# %%
prodRes=requests.get(productLink)

# %%
prodRes
# Out:
# <Response [200]>

# %%
prodRes.encoding='utf-8'

# %%
prod_html=bs(prodRes.text, "html.parser")

# %%
prod_html
# Out:
# <!DOCTYPE html>
# ...

# %%
commentboxes = prod_html.find_all('div', {'class': "_16PBlm"})

# %%
commentboxes
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Brilliant</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Good phone at this price point <br>Camera is by far the best among all other phones. Wide angle lens is quite accurate with colours and distortion is manageable. Portrait AI is good. HDR gives a sense of false positivity but makes the picture looks better compared to a dslr.<br/>iOS doesn't hang and makes multitasking pretty easy.<br/>Battery is ok. Extensive user like me (9-10h) screen time needs to charge twice daily.considering the usage its ok.<br/>Screen size and display is awesome. Fits into jeans eas...</br></div><span class="_1BWGvX"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202110/blobio-imr-202110
# ...

# %%
filename="iphone"+".csv"

# %%
filename
# Out:
# 'iphone.csv'

# %%
fw=open(filename, 'w')

# %%
headers="product, Customer Name, Rating, Heading, Comment \n"

# %%
fw.write(headers)
# Out:
# 50

# %%
reviews=[]

# %%
for commentbox  in commentboxes:
    name = commentbox.div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text
    print(name)
# Out:
# Saikat Chakraborty
# Prabhu Prasad
# Ujjal Saikia
# Vishal Patil
# Sanjay K.R.
# Akash Kumar M R
# HIMANSHU  RAWAT
# kiran kothapalli
# Rohit Sutar®
# Sajid C U
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-04848e1f9180> in <module>
#       1 for commentbox  in commentboxes:
# ----> 2     name = commentbox.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text
#       3     print(name)
#       4
#       5
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
for commentbox  in commentboxes:
    #name = commentbox.div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text
    rating=commentbox.div.div.div.div.text
    commentHead = commentbox.div.div.div.p.text
    comtag = commentbox.div.div.find_all('div', {'class': ''})
    custComment = comtag[0].div.text
    mydict = {"Product": 'iphone', "Name": "phone", "Rating": rating, "CommentHead": commentHead,
                          "Comment": custComment}
    reviews.append(mydict)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-31842eb8e6a3> in <module>
#       1 for commentbox  in commentboxes:
#       2     #name = commentbox.div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text
# ----> 3     rating=commentbox.div.div.div.div.text
#       4     commentHead = commentbox.div.div.div.p.text
#       5     comtag = commentbox.div.div.find_all('div', {'class': ''})
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
from urllib.request import urlopen

# %%
url = "http://olympus.realpython.org/profiles/aphrodite"

# %%
page=urlopen(url)

# %%
page
